# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect('/Users/zphilipp/git/research/dealsdb/deals_db.db')
cursor = conn.cursor()
# Vytvoření tabulky (pokud neexistuje)
cursor.execute('''DROP TABLE IF EXISTS deals''')
cursor.execute('''DROP TABLE IF EXISTS redemption''')
cursor.execute('''DROP TABLE IF EXISTS merchant''')
cursor.execute('''DROP TABLE IF EXISTS customer_taxonomy''')
cursor.execute('''DROP TABLE IF EXISTS deal_division''')
cursor.execute('''
CREATE TABLE IF NOT EXISTS deals (
    deal_id TEXT,
    deal_uuid TEXT,
    deal_option_id TEXT,
    title TEXT,
    title_general TEXT,
    highlights TEXT,
    url TEXT,
    redemption_locations_id INT,
    is_bookable INT,
    value INT,
    price INT,
    dynamic_pricing_enabled INT,
    discount_percent INT,
    start_at DATE,
    end_at DATE,
    merchant_id TEXT,
    ui_treatment_id INT,
    gallery_title TEXT,
    small_image TEXT,
    med_image TEXT,
    margin INT,
    sale_price INT,
    sale_price_effective_date DATE,
    currency TEXT,
    rating_count INT,
    rating_value FLOAT,
    description TEXT,
    customer_category_id TEXT
)''')
cursor.execute('''
CREATE TABLE IF NOT EXISTS redemption (
    deal_uuid TEXT,
    id INT,
    name TEXT,
    country TEXT,
    state TEXT,
    postal_code INT,
    street_address1 TEXT,
    lat FLOAT,
    lon FLOAT,
    geo_type TEXT,
    city TEXT,
    city_permalink TEXT,
    neighborhood TEXT
);
''')
cursor.execute('''
CREATE TABLE IF NOT EXISTS merchant (
    id TEXT PRIMARY KEY,
    name TEXT
);
''')
cursor.execute('''
CREATE TABLE IF NOT EXISTS customer_taxonomy (
    id TEXT PRIMARY KEY,
    name TEXT,
    link TEXT,
    parent_id TEXT
);
''')
cursor.execute('''
    CREATE TABLE IF NOT EXISTS deal_division (
        deal_id TEXT,
        id TEXT,
        name TEXT,
        permalink TEXT
);
''')
cursor.execute('''
    CREATE TABLE IF NOT EXISTS deal_location (
        deal_uuid TEXT,
        lat TEXT,
        lon TEXT
);
''')
conn.commit()
conn.close()

# %%
def insertLocations(deal_uuid, lat, lon,c, conn):

        try:
            c.execute("""
INSERT INTO deal_location (deal_uuid, lat, lon)
VALUES (?, ?, ?)""",
            (deal_uuid, lat, lon))
        except:
            print (d)
            raise


def insertRedemption(deal_uuid, r, c, conn):
    for d in r:
        try:
            c.execute("""
INSERT INTO redemption (
    deal_uuid, id, name, country, state, postal_code, street_address1,
    lat, lon, geo_type, city, city_permalink, neighborhood)
VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)""",
            (deal_uuid, d.get('id', None), d.get('name', ""), d['country'], 
            d.get('state', ""), d.get('postalCode', None), d['streetAddress1'], d.get('lat', None),
            d.get('lon', None), d.get('geo', {}).get("type", ""), d.get('city', ""),
            d.get('city_object', {}).get('permalink', ''), d.get('neighborhood', "")))

            insertLocations(deal_uuid, d.get('lat'), d.get('lon'), c, conn)
        except:
            print (d)
            raise

def insertDivision(deal_id, d, c, conn):
    data = d.get("divisions", None)

    for d in data:
        try:
            c.execute("""
INSERT INTO deal_division (
    deal_id, id, name, permalink )
VALUES (?, ?, ?, ?)""", (deal_id, d.get('id', None), d.get('name', ""), d.get('permalink', "")))
        except:
            print (d)
            raise

def insertMerchant(d, c, conn):
    try:
        c.execute("""
INSERT INTO merchant (id, name)
VALUES (?, ?)""",
            (d['merchant_id'], d['merchant_name']))
    except:
        pass
        #raise

def insertCustomerTaxonomy(d, c, conn):
    try:
        d = d[0]
        categories = []
        if d.get("top_category_guid", ""):
            categories.append({
                "id" : d.get("top_category_guid", ""),
                "name" : d.get("top_category", ""),
                "link" : d.get("top_category_permalink", ""),
                "parent" : None})
        if d.get("category_guid", ""):
            categories.append({
                "id" : d.get("category_guid", ""),
                "name" : d.get("category", ""),
                "link" : d.get("category_permalink", ""),
                "parent" : d.get("top_category_guid", "")})
        if d.get("category2_guid", ""):
            categories.append({
                "id" : d.get("category2_guid", ""),
                "name" : d.get("category2", ""),
                "link" : d.get("category2_permalink", ""),
                "parent" : d.get("category_guid", "")})
        if d.get("category3_guid", ""):
            categories.append({
                "id" : d.get("category3_guid", ""),
                "name" : d.get("category3", ""),
                "link" : d.get("category3_permalink", ""),
                "parent" : d.get("category2_guid", "")})
        if d.get("category4_guid", ""):
            categories.append({
                "id" : d.get("categor4_guid", ""),
                "name" : d.get("category4", ""),
                "link" : d.get("category4_permalink", ""),
                "parent" : d.get("category3_guid", "")})
        if d.get("category5_guid", ""):
            categories.append({
                "id" : d.get("categor5_guid", ""),
                "name" : d.get("category5", ""),
                "link" : d.get("category5_permalink", ""),
                "parent" : d.get("category4_guid", "")})
        for ca in categories:
            c.execute("""
INSERT OR IGNORE INTO customer_taxonomy (id, name, link, parent_id)
VALUES (?, ?, ?, ?)""", (ca['id'], ca['name'], ca['link'], ca['parent']))
    except:
        print (categories)
        raise
        #return None
    return categories.pop()["id"]
    
def insertDeal(d, c, conn):
    if d.get("is_bookable", None):
        is_bookable = d["is_bookable"]
    else:
        is_bookable = None
        
    if d.get("merchant_id", None):
        insertMerchant(d, c, conn)

    if d.get('customer_taxonomy_hierarchy', []):
        customer_category_id = insertCustomerTaxonomy(
            d.get('customer_taxonomy_hierarchy', []), c, conn)
    else:
        customer_category_id = None

    if d.get("redemption_locations", None):
        insertRedemption(d["deal_uuid"], d["redemption_locations"], c, conn)

    if d.get("divisions", None):
        insertDivision(d['deal_id'], d, c, conn)
        

    c.execute("""
INSERT INTO deals (
    deal_id, deal_uuid, deal_option_id, title, highlights, title_general, url, redemption_locations_id,
    is_bookable, value, price, dynamic_pricing_enabled, discount_percent, start_at, end_at,
    merchant_id, ui_treatment_id, gallery_title, small_image, med_image, margin,
    sale_price, sale_price_effective_date, currency, rating_count, rating_value, description,
    customer_category_id)

VALUES
    (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)

""", (
    d['deal_id'], d["deal_uuid"], d["deal_option_id"], d.get("title", None), d.get("title", "highlights"), d["title_general"],
    d["url"], 0,
    is_bookable,
    d["value"], d["price"],
    d.get("dynamicPricingEnabled", ""), d.get("discount_percent", None), d["start_at"], d["end_at"],
    d.get("merchant_id", None), d.get("ui_treatment_id", None), d["gallery_title"], d["small_image"],
    d["med_image"], d.get("margin", None), d["sale_price"], d["sale_price_effective_date"],
    d["currency"], d.get("rating_count", None), d.get("rating_value", None), d.get("description", ""),
    customer_category_id
))
    #if d.get("divisions", None):
    #    insertDicisions(d["divisions"], c, conn)

    #if len(d) > 1:
    #    print ("Div: %s" % d)

    
    conn.commit()

# %%
import json
import os
directory = 'deals_data/saved_deals/'
conn = sqlite3.connect('deals_db.db')
cursor = conn.cursor()

cursor.execute("""DELETE FROM deals""")
cursor.execute("""DELETE FROM redemption""")
cursor.execute("""DELETE FROM merchant""")
cursor.execute("""DELETE FROM customer_taxonomy""")
cursor.execute("""DELETE FROM deal_division""")
conn.commit()
i = 0
# Čtení původního JSON souboru po řádcích
for filename in os.listdir(directory):
    
    with open('deals_data/saved_deals/%s' % filename, 'r', encoding='UTF-8') as file:
        data = file.read()
        d = json.loads(data)
        insertDeal(d, cursor, conn)

    conn.commit()

conn.close()
        
    #i = i + 1
    #if (i > 1):
    #    break
# Out:
# {'deal_id': 'texas-rotisserie-and-grill-2581-broadway-2', 'deal_option_id': '6d5e65e3-cd62-4b0a-a35d-14caa0b49fa1', 'deal_uuid': 'ce3810b1-66c7-4be9-8dd1-9d01a66f273d', 'url': 'https://www.groupon.com/deals/texas-rotisserie-and-grill-2581-broadway-2', 'redemption_locations': [{'uuid': 'a60554f9-730d-b06a-768b-015071afc5be', 'id': 84179728, 'name': 'Manhattan', 'country': 'US', 'state': 'NY', 'postalCode': '10025', 'streetAddress1': '2581 Broadway', 'lat': 40.7955427, 'lng': -73.9714899, 'geo': {'coordinates': [-73.9714899, 40.7955427], 'type': 'Point'}, 'city': 'New York', 'city_object': {'name': 'New York', 'permalink': 'new-york-ny'}, 'neighborhood': 'Manhattan', 'neighborhood_object': {'name': 'Manhattan', 'permalink': 'upper-west-side-new-york-ny'}}], 'is_bookable': False, 'value': 2099, 'price': 1679, 'dynamicPricingEnabled': True, 'discount_percent': 28, 'start_at': '2025-01-13T05:00:00.000Z', 'end_at': '2049-05-22T03:59:59.000Z', 'merchant_name': 'Texas Rotisserie And Grill  2581 Broadway', 'merchant_id': 'texas-rotisserie-grill-2581-broadway', 'ui_treatment_id': '03567e7f-40b5-4743-9466-2ec2d75631af', 'grt_taxonomy_hierarchy': [{'category': 'L2 - Food & Drink', 'category2': 'L3 - American Food', 'category2_guid': 'e0920f35-e890-4a7c-b0da-3650c30d53e9', 'category3': 'L4 - BBQ & Southern', 'category3_guid': '3024d076-c07c-49a4-af06-1bb12326a150', 'category4': 'L5 - BBQ', 'category4_guid': '1789a514-06c4-47cf-899d-f79613b66709', 'category5': 'L6 - Barbeque / BBQ', 'category5_guid': 'cdf8605a-df2e-4f3f-8c7b-583feb796c9c', 'category_guid': 'acee6079-e2bc-4329-8087-78924b9733f6', 'top_category': 'L1 - Local', 'top_category_guid': 'ea3a7b4b-10f7-4fdd-9e03-6a34e96d0c88'}], 'customer_taxonomy_hierarchy': [{'category': 'Food & Drink', 'category2': 'Restaurants', 'category2_guid': '5b99fc65-2d2f-48d8-ac26-c4b629c0a439', 'category2_permalink': 'restaurants', 'category3': 'BBQ Restaurants', 'category3_guid': '840d6273-fa64-492c-bfd4-8896c88d1cd7', 'category3_permalink': 'bbq-restaurants', 'category_guid': 'f052f491-36c2-406f-a196-be2c59d281f4', 'category_permalink': 'food-and-drink', 'top_category': 'Local', 'top_category_guid': 'c09790ba-a6b9-40fc-ad81-4cdf25260b5e', 'top_category_permalink': 'local'}], 'title': 'Quarter Rotisserie Chicken Meal', 'gallery_title': '\xa0Fire Up Flavor:\xa0Quarter Rotisserie Chicken Meal', 'issoldout': False, 'small_image': 'https://img.grouponcdn.com/bynder/37sFHFhaNbX972eRebf9phbwEM72/37-2048x1229/v1/t200x300.jpg', 'med_image': 'https://img.grouponcdn.com/bynder/37sFHFhaNbX972eRebf9phbwEM72/37-2048x1229/v1/t300x182.jpg', 'margin': 302, 'constraints': [{'categoryIds': ['1560ef81-5e83-4b16-a1d5-6de511f35d9a'], 'enforcedAt': '2025-01-13T05:00:00Z', 'enforcedUntil': '2025-01-14T05:00:00Z', 'type': 'forbidden'}, {'categoryIds': ['b7414015-3e49-4897-a928-e7f57f5bed4a', 'df729545-180f-45d5-aefa-8eee53749f25', 'a376dfa4-6df7-4af4-ada9-b03036748468', '90ce0d47-4d52-4645-93cd-1d93ac6cb9f9', '28457a91-f0d5-40a8-9965-572461b2e9cd', '65cc8b7e-9050-4448-a980-b9ff3e25d12b'], 'enforcedAt': '2025-01-13T05:00:00Z', 'enforcedUntil': '2025-01-14T05:00:00Z', 'type': 'forbidden'}, {'categoryIds': ['1560ef81-5e83-4b16-a1d5-6de511f35d9a'], 'enforcedAt': '2025-01-14T05:00:00Z', 'enforcedUntil': '2025-01-20T04:59:59Z', 'type': 'forbidden'}, {'categoryIds': ['b7414015-3e49-4897-a928-e7f57f5bed4a', 'df729545-180f-45d5-aefa-8eee53749f25', 'a376dfa4-6df7-4af4-ada9-b03036748468', '90ce0d47-4d52-4645-93cd-1d93ac6cb9f9', '28457a91-f0d5-40a8-9965-572461b2e9cd', '65cc8b7e-9050-4448-a980-b9ff3e25d12b'], 'enforcedAt': '2025-01-14T05:00:00Z', 'enforcedUntil': '2025-01-20T04:59:59Z', 'type': 'forbidden'}, {'categoryIds': ['1560ef81-5e83-4b16-a1d5-6de511f35d9a'], 'enforcedAt': '2025-01-20T04:59:59Z', 'enforcedUntil': '2049-05-22T03:59:59Z', 'type': 'forbidden'}, {'categoryIds': ['b7414015-3e49-4897-a928-e7f57f5bed4a', 'df729545-180f-45d5-aefa-8eee53749f25', 'a376dfa4-6df7-4af4-ada9-b03036748468', '90ce0d47-4d52-4645-93cd-1d93ac6cb9f9', ' ...
# {'uuid': 'a60554f9-730d-b06a-768b-015071afc5be', 'id': 84179728, 'name': 'Manhattan', 'country': 'US', 'state': 'NY', 'postalCode': '10025', 'streetAddress1': '2581 Broadway', 'lat': 40.7955427, 'lng': -73.9714899, 'geo': {'coordinates': [-73.9714899, 40.7955427], 'type': 'Point'}, 'city': 'New York', 'city_object': {'name': 'New York', 'permalink': 'new-york-ny'}, 'neighborhood': 'Manhattan', 'neighborhood_object': {'name': 'Manhattan', 'permalink': 'upper-west-side-new-york-ny'}}
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[12], line 20
#      18         data = file.read()
#      19         d = json.loads(data)
# ---> 20         insertDeal(d, cursor, conn)
#      22     conn.commit()
#      24 conn.close()
#
# Cell In[11], line 121, in insertDeal(d, c, conn)
#     118     customer_category_id = None
#     120 if d.get("redemption_locations", None):
# --> 121     insertRedemption(d["deal_uuid"], d["redemption_locations"], c, conn)
#     123 if d.get("divisions", None):
#     124     insertDivision(d['deal_id'], d, c, conn)
#
# Cell In[11], line 27, in insertRedemption(deal_uuid, r, c, conn)
#      16         try:
#      17             c.execute("""
#      18 INSERT INTO redemption (
#      19     deal_uuid, id, name, country, state, postal_code, street_address1,
#    (...)
#      24             d.get('lon', None), d.get('geo', {}).get("type", ""), d.get('city', ""),
#      25             d.get('city_object', {}).get('permalink', ''), d.get('neighborhood', "")))
# ---> 27             insertLocations(deal_uuid, d.get('lat'), d.get('lon'), c, conn)
#      28         except:
#      29             print (d)
#
# Cell In[11], line 4, in insertLocations(deal_uuid, lat, lon, c, conn)
#       1 def insertLocations(deal_uuid, lat, lon,c, conn):
#       3         try:
# ----> 4             c.execute("""
#       5 INSERT INTO deal_location (
#       6     deal_uuid, lat, lon
#       7 VALUES (?, ?, ?)""",
#       8             (deal_uuid, lat, lon))
#       9         except:
#      10             print (d)
#
# OperationalError: near "VALUES": syntax error

# %%
with open('deals_data/saved_deals/deal_33ee55dc-4449-49bc-9636-96361bb78fcb.json', 'r') as f:
    d = json.load(f)
d
# Out:
# {'deal_id': 'viator-sebago-trails-paddling-co',
#  'deal_option_id': 'e57cd9d8-8652-4f06-b14f-406b8dbc67c0',
#  'deal_uuid': '33ee55dc-4449-49bc-9636-96361bb78fcb',
#  'url': 'https://www.groupon.com/deals/viator-sebago-trails-paddling-co',
#  'redemption_locations': [],
#  'is_bookable': True,
#  'value': 5900,
#  'price': 5900,
#  'discount_percent': 0,
#  'start_at': '2021-01-26T20:39:50.000Z',
#  'end_at': '2040-01-01T00:00:00.000Z',
#  'merchant_name': 'Sebago Trails Paddling Co.',
#  'merchant_id': 'viator-2',
#  'ui_treatment_id': '649ddf1b-203d-4574-91d1-812a35fdf85c',
#  'grt_taxonomy_hierarchy': [{'category': 'L2 - Things to Do - Leisure',
#    'category2': 'L3 - Tours & Tastings',
#    'category2_guid': '54d5094d-57b2-4cfc-a1fd-5f6cf3e82c97',
#    'category3': 'L4 - Tours & Tastings',
#    'category3_guid': 'cd6290e0-6aac-452f-9955-3b6835313c05',
#    'category4': 'L5 - Tours & Tastings',
#    'category4_guid': '351bb479-a133-4756-acce-43b621cfccb9',
#    'category5': 'L6 - Tour / Attraction Passes',
#    'category5_guid': '62ed3098-dafc-48bb-ad66-3041553ffbfb',
#    'category_guid': '8c370b4b-3712-48ef-832e-75c7d6f75001',
#    'top_category': 'L1 - Local',
#    'top_category_guid': 'ea3a7b4b-10f7-4fdd-9e03-6a34e96d0c88'}],
#  'customer_taxonomy_hierarchy': [{'category': 'Things To Do',
#    'category2': 'Sightseeing & Tours',
#    'category2_guid': '2afb5ba6-75bc-497e-a53a-be118d00f59a',
#    'category2_permalink': 'sightseeing-and-tours',
#    'category3': 'City & Landmark Tours',
#    'category3_guid': 'e0ceb58d-8067-4c9f-a092-17c200389a9e',
#    'category3_permalink': 'city-landmark-tours',
#    'category_guid': '938de4d2-b8f5-41c7-860f-94ded05f43c8',
#    'category_permalink': 'things-to-do',
#    'top_category': 'Local',
#    'top_category_guid': 'c09790ba-a6b9-40fc-ad81-4cdf25260b5e',
#    'top_category_permalink': 'local'},
#   {'category': 'Things To Do',
#    'category2': 'Sightseeing & Tours',
#    'category2_guid': '2afb5ba6-75bc-497e-a53a-be118d00f59a',
#    'category2_permalink': 'sightseeing-and-tours',
#    'category3': 'Attraction Pass',
#    'category3_guid': '7dc2bdef-fc57-4e41-925c-42e863dc54be',
#    'category3_permalink': 'attraction-pass',
#    'category_guid': '938de4d2-b8f5-41c7-860f-94ded05f43c8',
#    'category_permalink': 'things-to-do',
#    'top_category': 'Local',
#    'top_category_guid': 'c09790ba-a6b9-40fc-ad81-4cdf25260b5e',
#    'top_category_permalink': 'local'}],
#  'title': 'Sunset Tour by Kayak on Sebago Lake Maine',
#  'gallery_title': 'Sunset Tour by Kayak on Sebago Lake Maine',
#  'issoldout': False,
#  'small_image': 'https://img.grouponcdn.com/pwa_test/4DxQFdS79znektz9jRPh3bHfzY9R/4D-720x480/v1/t200x300.jpg',
#  'med_image': 'https://img.grouponcdn.com/pwa_test/4DxQFdS79znektz9jRPh3bHfzY9R/4D-720x480/v1/t300x182.jpg',
#  'constraints': [{'categoryIds': ['0c5401a4-7d96-44f8-a229-7403453512e8'],
#    'enforcedAt': '2021-01-26T20:39:50Z',
#    'enforcedUntil': '2040-01-01T00:00:00Z',
#    'type': 'forbidden'},
#   {'categoryIds': ['0f3b70b4-acb4-4a60-9f28-4c68fbe41210'],
#    'enforcedAt': '2021-01-26T20:39:50Z',
#    'enforcedUntil': '2040-01-01T00:00:00Z',
#    'type': 'forbidden'},
#   {'categoryIds': ['17085de1-2bd6-4180-8c89-196112ef74b5'],
#    'enforcedAt': '2021-01-26T20:39:50Z',
#    'enforcedUntil': '2040-01-01T00:00:00Z',
#    'type': 'allowed'},
#   {'categoryIds': ['2ab87954-ff57-41f1-a3ed-d319fc8d7d59'],
#    'enforcedAt': '2021-01-26T20:39:50Z',
#    'enforcedUntil': '2040-01-01T00:00:00Z',
#    'type': 'allowed'},
#   {'categoryIds': ['2f74e683-52a7-484a-97a1-c32f74deb74d'],
#    'enforcedAt': '2021-01-26T20:39:50Z',
#    'enforcedUntil': '2040-01-01T00:00:00Z',
#    'type': 'allowed'},
#   {'categoryIds': ['691215de-8fde-400d-ba8f-946684a75062'],
#    'enforcedAt': '2021-01-26T20:39:50Z',
#    'enforcedUntil': '2040-01-01T00:00:00Z',
#    'type': 'allowed'},
#   {'categoryIds': ['b2f7159e-0755-4ade-96be-a8d3767c3e49'],
#    'enforcedAt': '2021-01-26T20:39:50Z',
#    'enforcedUntil': '2040-01-01T00:00:00Z',
#    'type': 'allowed'},
#   {'categoryIds': ['e2b4c106-e03d-4025-8b15-8970616f2233'],
#    'enforcedAt': '2021-01-26T20:39:50Z',
#    'enforcedUntil': '2040-01-01T00:00:00Z',
#    'type': 'forbidden'},
#   {'categoryIds': ['f81ab6bd-93e5-431f-b08c-456c5ff5bfa7'],
#    'enforcedAt': '2021-01-26T20:39:50Z',
#    'enforcedUntil': '2040-01-01T00:00:00Z',
#    'type': 'allowed'},
#   {'categoryIds': ['347a3908-0c5f-405c-b1f7-2112312130f1',
#     'b7414015-3e49-4897-a928-e7f57f5bed4a',
#     'df729545-180f-45d5-aefa-8eee53749f25',
#     '8fa844fc-6318-4b4c-b5aa-5d7dae04333e',
#     '31a9baa2-2a3c-4f83-8ebc-e352cd03a90a',
#     'a376dfa4-6df7-4af4-ada9-b03036748468',
#     '90ce0d47-4d52-4645-93cd-1d93ac6cb9f9',
#     '28457a91-f0d5-40a8-9965-572461b2e9cd',
#     '01e404ce-46cc-433f-909b-a6ed9b221bd4',
#     'c91f0338-408a-4d38-a0bb-f954ae27d4c4',
#     '65cc8b7e-9050-4448-a980-b9ff3e25d12b',
#     '51ece65d-b105-4423-ad42-6c84d440ee0a'],
#    'enforcedAt': '2021-01-26T20:39:50Z',
#    'enforcedUntil': '2040-01-01T00:00:00Z',
#    'type': 'forbidden'}],
#  'merchandising_tags': [{'id': 'mts-experiences-physical-redemption',
#    'name': 'mts-experiences-physical-redemption'},
#   {'id': 'mts-division-trending-top-150',
#    'name': 'mts-division-trending-top-150'},
#   {'id': 'mts-buy-it-again', 'name': 'mts-buy-it-again'},
#   {'id': 'things-to-do-109', 'name': 'things-to-do-109'},
#   {'id': 'things-to-do-gatherings-2016',
#    'name': 'things-to-do-gatherings-2016'},
#   {'id': 'mts-division-activation-top-150',
#    'name': 'mts-division-activation-top-150'},
#   {'id': 'things-to-do-049', 'name': 'things-to-do-049'},
#   {'id': 'things-to-do-050', 'name': 'things-to-do-050'},
#   {'id': 'mts-division-trending-top50-leisure',
#    'name': 'mts-division-trending-top50-leisure'},
#   {'id': 'things-to-do-gifting-and-gathering-2016',
#    'name': 'things-to-do-gifting-and-gathering-2016'},
#   {'id': 'groupon-deals-3889', 'name': 'groupon-deals-3889'},
#   {'id': 'mts-zero-sold-quantity-30d', 'name': 'mts-zero-sold-quantity-30d'},
#   {'id': 'groupon-deals-137', 'name': 'groupon-deals-137'},
#   {'id': 'groupon-deals-176', 'name': 'groupon-deals-176'},
#   {'id': 'mts-min-5-units-in-stock', 'name': 'mts-min-5-units-in-stock'},
#   {'id': 'mts-zero-sold-quantity-15d', 'name': 'mts-zero-sold-quantity-15d'},
#   {'id': 'mts-division-trending-top-50-mobile-only',
#    'name': 'mts-division-trending-top-50-mobile-only'},
#   {'id': 'groupon-deals-134', 'name': 'groupon-deals-134'},
#   {'id': 'things-to-do-035', 'name': 'things-to-do-035'}],
#  'sale_price': '',
#  'sale_price_effective_date': '',
#  'currency': 'USD',
#  'divisions': [{'name': 'Portland, ME',
#    'permalink': 'portland-me',
#    'uuid': 'b64d9b66-d5dc-4e42-a460-e0f5fa7ff6ce'}],
#  'channel': 'g1',
#  'subchannel': '3pip',
#  'inventory_service_id': 'tpis',
#  'deal_quality': '',
#  'restricted': False,
#  'restricted_reason': [],
#  'title_general': 'Sunset Tour by Kayak on Sebago Lake Maine',
#  'highlights': '<p>Discover the serene beauty of water-carved bends and meandering streams, where local wildlife thrives against a backdrop of rustic charm. As we embark on our journey, we&#39;ll navigate the gentle twists and turns of a meandering stream, revealing the untouched beauty. Let the tranquil waters carry you along as you immerse yourself in the sights and sounds of the natural world.\nThroughout the tour, our knowledgeable Registered Maine Guide will regal you with captivating stories, bringing the scene to life with native lore and insights. Surrounded by panoramic views we pause and marvel as the sun sets behind the Towering pines. Whether you&#39;re a seasoned paddler or a complete beginner, rest assured this outing requires no previous experience - just a sense of adventure and a desire to unwind.</p>',
#  'description': '<div style="font-size: 14px; padding-left: 16px; padding-right: 48px; background-color: #E8F4FC; border-radius: 6px; overflow: hidden; padding-top: 16px; padding-bottom: 12px; margin-top: 12px; margin-bottom: 12px;">\n<img style="float: left; margin-top: 8px; margin-right: 16px; width: 29px;" src="https://img.grouponcdn.com/test/4HErPZoyjNNCtC2F9WRrwXNaG8JK/groupon_trust_96-96x96" alt="Best Price Guarantee" />\n<div style="overflow: hidden; color: #000000;">\n<strong>Best Price Guarantee</strong>\n<br />If you find a better price somewhere else, let us know. We&#39;ll cover the difference, worry free. See full details at gr.pn/bpg\n</div>\n</div>\n<p>\n<p><strong>Departure Point</strong><br /><ul><li>Travel north on Route 302 (Roosevelt Trail). First parking lot on right after the Route 85 intersection.</li></ul><br /><strong>Return Details</strong><br /><ul><li>Travel north on Route 302 (Roosevelt Trail). First parking lot on right after the Route 85 intersection.</li></ul><br /><strong>Duration</strong><br />2 hours<br /><br /><strong>Languages Available</strong><br /><ul><li>Human tour guide - English</li></ul><br /><h3>Points of Interest</h3><br /><strong>Stop At:</strong> Sebago Lake<br />, , Maine<br />Explore the natural beauty of Sebago Lake and adjacent streams to spot native birds, fish, turtles, ducks, and the picturesque views of the sun setting over the tall pines trees. <br />Duration: 2 hours<br /><h3>Additional Information</h3><ul><li>Suitable for all physical fitness levels</li></ul><strong>Inclusions</strong><br /><ul><li>Kayak, paddle and life Jacket included in tour price</li></ul><br /><strong>Redemption Instructions</strong><br />Please check-in at rental counter<br /><br /><strong>Voucher Info</strong><br />Mobile or paper ticket accepted<br /></p>\n<strong>The tour identified in this promotion is made available through Viator. Groupon is not affiliated with or sponsored by the Sebago Trails Paddling Co. in connection with this deal. Please contact Groupon customer service for all inquiries related to this offer. Inquiries placed to Viator will be directed back to Groupon.</strong>\n<br/><br/>\n<strong>This offer is not eligible for promo codes.</strong></p>',
#  'image_links': ['https://img.grouponcdn.com/pwa_test/4DxQFdS79znektz9jRPh3bHfzY9R/4D-720x480/v1/c1200x627.jpg',
#   'https://img.grouponcdn.com/pwa_test/4UEWtgLguJftAuxk2x22syHc2Ben/4U-719x480/v1/c1200x627.jpg',
#   'https://img.grouponcdn.com/pwa_test/gdTDy2US78P4vn13iENEBCBrD12/gd-720x480/v1/c1200x627.jpg',
#   'https://img.grouponcdn.com/pwa_test/2PHhgYbhzDBMRMRdJkVqZUDGMrfy/2P-720x480/v1/c1200x627.jpg',
#   'https://img.grouponcdn.com/pwa_test/PNxam2K9v4tcYXvLeCgTAbsnJp4/PN-719x480/v1/c1200x627.jpg',
#   'https://img.grouponcdn.com/pwa_test/2zVbRNpkNCLbToMTcdYZ3mGNtaTN/2z-720x480/v1/c1200x627.jpg',
#   'https://img.grouponcdn.com/pwa_test/23DyPMTNpxyB5vaiwegrYAyc12ei/23-720x480/v1/c1200x627.jpg',
#   'https://img.grouponcdn.com/pwa_test/44NG5Fc5Taiz7akNc1HtBmxuCAQq/44-720x480/v1/c1200x627.jpg',
#   'https://img.grouponcdn.com/pwa_test/6DykSCciXPHhPSYG6AqCi2P71hu/6D-720x480/v1/c1200x627.jpg',
#   'https://img.grouponcdn.com/pwa_test/fMzvhdSscBUEEyHi4UDnyvDC1Gu/fM-719x480/v1/c1200x627.jpg',
#   'https://img.grouponcdn.com/pwa_test/nD1Vn2SEGr3g9YmXkwZAenriSef/nD-719x480/v1/c1200x627.jpg',
#   'https://img.grouponcdn.com/pwa_test/4TwPuTGzpGYuHwyu8TVpaWUMLFS6/4T-720x480/v1/c1200x627.jpg',
#   'https://img.grouponcdn.com/pwa_test/2aB2fHq8DMnWvTCw6Yde6FzfJX3r/2a-720x480/v1/c1200x627.jpg',
#   'https://img.grouponcdn.com/pwa_test/3jjNPAqhFfhmSjM21zTJiZKykp4/3j-720x479/v1/c1200x627.jpg'],
#  'show_discount': False,
#  'redemptionPolicy': 'default',
#  'timestamp': 1738918754,
#  'brands': ['groupon', 'livingsocial'],
#  'characteristics': [{'descriptors': [],
#    'uuid': 'de740ad4-7da2-41c2-bcb9-6822521f9fe4'}],
#  'adSafe': True,
#  'eligible_for_groupon_incentives': False,
#  'channel_name': 'Local',
#  'channel_id': '2064915a-347c-410d-a18a-76556d5540fe',
#  'pds_id': '0001e3b1-da7a-42df-bd46-806fb436a756',
#  'pds_name': 'Tour / Attraction Passes',
#  'city_geo': {'coordinates': [-70.2553, 43.6615], 'type': 'Point'},
#  'inventory_product_id': 'e7c19e25-f59c-450f-a840-da57aed8c46f',
#  'minimumPurchaseQuantity': 1,
#  'deal_supply_source': '3PIP',
#  'display_options': [{'enabled': False, 'name': 'discount'},
#   {'enabled': False, 'name': 'quantity'},
#   {'enabled': True, 'name': 'timer'},
#   {'name': 'merchandisingType', 'value': 'other'},
#   {'enabled': True, 'name': 'showRedemptionLocations'},
#   {'enabled': True, 'name': 'showPrice'},
#   {'enabled': False, 'name': 'discountPercentageBadge'},
#   {'enabled': True,
#    'name': 'showCancellationPolicyBanner',
#    'value': 'Up to 24 hours before your scheduled admission.'}],
#  'deal_state': 'active',
#  'deal_attributes': {'hotel_amenities': [],
#   'hotel_categories_placeholder': [],
#   'hotel_inclusions_placeholder': [],
#   'hotel_exclusions_placeholder': []},
#  'gifting_percentage_7d': 0.0,
#  'gifting_percentage_30d': 0.0,
#  'gifting_percentage_365d': 0.0}

# %%
conn.close()

# %%
import json
import os
directory = 'deals_data/saved_deals/'
i = 0
# Čtení původního JSON souboru po řádcích
deals = []
for filename in os.listdir(directory):
    with open('deals_data/saved_deals/%s' % filename, 'r') as f:
        d = json.load(f)

        c = d.get('customer_taxonomy_hierarchy', None)[0]

        if (
            c.get("category_guid", None) == '80082ffd-dbc6-477a-8067-c084db4fb7cc' or
            c.get("category2_guid", None) == '80082ffd-dbc6-477a-8067-c084db4fb7cc' or
            c.get("category3_guid", None) == '80082ffd-dbc6-477a-8067-c084db4fb7cc' or
            c.get("category4_guid", None) == '80082ffd-dbc6-477a-8067-c084db4fb7cc' or
            c.get("category4_guid", None) == '80082ffd-dbc6-477a-8067-c084db4fb7cc'
        ):
            deals.append(c)  
        if i > 2:
            break

print(json.dumps(deals, indent=4))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 11
#       8 with open('deals_data/saved_deals/%s' % filename, 'r') as f:
#       9     d = json.load(f)
# ---> 11     c = d.get('customer_taxonomy_hierarchy', None)[0]
#      13     if (
#      14         c.get("category_guid", None) == '80082ffd-dbc6-477a-8067-c084db4fb7cc' or
#      15         c.get("category2_guid", None) == '80082ffd-dbc6-477a-8067-c084db4fb7cc' or
#    (...)
#      18         c.get("category4_guid", None) == '80082ffd-dbc6-477a-8067-c084db4fb7cc'
#      19     ):
#      20         deals.append(c)
#
# IndexError: list index out of range

# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect('deals_db.db')
cursor = conn.cursor()

c.execute("""
SELECT t.id, t.name, d.deal_id
FROM
    deals d JOIN customer_taxonomy t
        ON (d.customer_category_id=t.id)
GROUP BY t.id
ORDER BY t.id
""")


conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       3 conn = sqlite3.connect('deals_db.db')
#       4 cursor = conn.cursor()
# ----> 6 c.execute("""
#       7 SELECT t.id, t.name, d.deal_id
#       8 FROM
#       9     deals d JOIN customer_taxonomy t
#      10         ON (d.customer_category_id=t.id)
#      11 GROUP BY t.id
#      12 ORDER BY t.id
#      13 """)
#      16 conn.commit()
#      17 conn.close()
#
# NameError: name 'c' is not defined
