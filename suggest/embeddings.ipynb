# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
sentences = [
    "Massage oil",
    "Massage spa",
    "Beauty & Spas Massage Swedish Massage",
    "Oil Change & Maintenance",
    "Auto Repair & Maintenance"
]

for i, sentence in enumerate(sentences):
    print(f"{i}: {sentence}")

# Word embeddings
embeddings = model.encode(sentences)

# Display the similarity matrix
print("\nSimilarity Matrix:")
print(embeddings)
# Out:
# 0: Massage oil
# 1: Massage spa
# 2: Beauty & Spas Massage Swedish Massage
# 3: Oil Change & Maintenance
# 4: Auto Repair & Maintenance
#
# Similarity Matrix:
# [[-0.08211305 -0.02124043  0.05563774 ...  0.00077279  0.05629627
#    0.03794257]
#  [-0.04445589 -0.02205229  0.03294419 ... -0.03769324 -0.02575363
#   -0.00027607]
#  [-0.00196318 -0.01467103  0.03193342 ... -0.04249129  0.02011871
#   -0.01864022]
#  [-0.09328058 -0.02611593  0.14303546 ... -0.0343686   0.04817219
#    0.04698653]
#  [-0.10032664 -0.01238883  0.06903696 ... -0.02474346  0.03153863
#   -0.02106589]]
